# %%
import librosa
import scipy.io.wavfile
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import librosa.display

# %%
frame_length = 0.025 # 프레임을 일정 시간 단위로 쪼갬 (25ms)
frame_stride = 0.010 # 프레임이 겹치는 구간 (10ms)

for i in range(43):
    audio_path = 'D:\\sound\\human\\human_original\\human_'
    mel_path = 'D:\\sound\\human\\mel-spectrogram\\human_'
    num = i + 1
    a_name = audio_path + str(num) + '.wav'
    m_name = mel_path + str(num) + '.png'

    # mel-spectrogram
    # 음성 로드
    # y = 음성 데이터, sr = y의 sampling rate
    # sr은 default값 (22050) -> 44100으로 바꿔봄
    y, sr = librosa.load(a_name, sr=44100, duration=5)

    # wav_length = len(y)/sr
    # 시간 관점의 음성 데이터를 주파수 관점으로 변환
    input_nfft = int(round(sr*frame_length))
    input_stride = int(round(sr*frame_stride))

    # wav 파일을 melspectrogram으로 변환
    S = librosa.feature.melspectrogram(y=y, n_mels=40, n_fft=input_nfft, hop_length=input_stride)

    print("Wav length: {}, Mel_S shape:{}".format(len(y)/sr, np.shape(S)))

    plt.figure(figsize=(5, 2), frameon=False, dpi=50)
    # librosa.display.specshow(librosa.power_to_db(S, ref=np.max), y_axis='mel', sr=sr, hop_length=input_stride, x_axis='time')
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max), sr=sr, hop_length=input_stride) # 0.8.0 ver.
    # librosa.display.specshow(librosa.logamplitude(S, ref_power=np.max), sr=sr, hop_length=input_stride) # 0.4.2 ver.
    
    plt.savefig(m_name, format='png', bbox_inches='tight', pad_inches=0, facecolor='black')
    plt.show()
# Out:
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 3.179705215419501, Mel_S shape:(40, 318)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 0.7662585034013606, Mel_S shape:(40, 77)
# Wav length: 1.3320861678004534, Mel_S shape:(40, 134)
# Wav length: 1.9040362811791383, Mel_S shape:(40, 191)
# Wav length: 0.8272335600907029, Mel_S shape:(40, 83)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 3.7500226757369615, Mel_S shape:(40, 376)
# Wav length: 2.184013605442177, Mel_S shape:(40, 219)
# Wav length: 0.9675056689342404, Mel_S shape:(40, 97)
# Wav length: 0.597936507936508, Mel_S shape:(40, 60)
# Wav length: 1.3436281179138323, Mel_S shape:(40, 135)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 1.0484580498866214, Mel_S shape:(40, 105)
# Wav length: 0.9607482993197279, Mel_S shape:(40, 97)
# Wav length: 0.8489115646258504, Mel_S shape:(40, 85)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 5.0, Mel_S shape:(40, 501)
# Wav length: 1.663718820861678, Mel_S shape:(40, 167)
# Wav length: 1.7531065759637188, Mel_S shape:(40, 176)
# Wav length: 5.0, Mel_S shape:(40, 501)
